# %%
# !git clone https://github.com/GT-SALT/FormalityStyleTransfer.git
# Out:
# Cloning into 'FormalityStyleTransfer'...
# remote: Enumerating objects: 331, done.
# remote: Counting objects: 100% (331/331), done.
# remote: Compressing objects: 100% (249/249), done.
# remote: Total 331 (delta 76), reused 328 (delta 76), pack-reused 0
# Receiving objects: 100% (331/331), 751.45 KiB | 792.00 KiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 124 kB 13.0 MB/s
# ...

# %%
# %cd /content/FormalityStyleTransfer
# !unzip /content/drive/MyDrive/FormalityStyleTransfer/GYAFC.zip
# Out:
# /content/FormalityStyleTransfer
# Archive:  /content/drive/MyDrive/FormalityStyleTransfer/GYAFC.zip
#    creating: dataset/
#   inflating: __MACOSX/._dataset
#   inflating: dataset/.DS_Store
#   inflating: __MACOSX/dataset/._.DS_Store
#    creating: dataset/test/
#   inflating: __MACOSX/dataset/._test
#    creating: dataset/model_outputs/
#   inflating: __MACOSX/dataset/._model_outputs
#    creating: dataset/tune/
#   inflating: __MACOSX/dataset/._tune
#    creating: dataset/train/
#   inflating: __MACOSX/dataset/._train
#   inflating: dataset/test/informal.ref1
#   inflating: __MACOSX/dataset/test/._informal.ref1
#   inflating: dataset/test/informal.ref0
#   inflating: __MACOSX/dataset/test/._informal.ref0
#   inflating: dataset/test/formal
#   inflating: __MACOSX/dataset/test/._formal
#   inflating: dataset/test/formal.ref3
#   inflating: __MACOSX/dataset/test/._formal.ref3
#   inflating: dataset/test/formal.ref2
#   inflating: __MACOSX/dataset/test/._formal.ref2
# ...

# %%
# !mv /content/FormalityStyleTransfer/dataset /content/FormalityStyleTransfer/grammarly
# !mv /content/FormalityStyleTransfer/grammarly/tune /content/FormalityStyleTransfer/grammarly/val
# !cp -r /content/FormalityStyleTransfer/grammarly/test /content/FormalityStyleTransfer/grammarly/plain

# %%
# !mv /content/FormalityStyleTransfer/grammarly/train/informal /content/FormalityStyleTransfer/grammarly/train/source
# !mv /content/FormalityStyleTransfer/grammarly/train/formal /content/FormalityStyleTransfer/grammarly/train/target

# %%
# !mv /content/FormalityStyleTransfer/grammarly/test/informal /content/FormalityStyleTransfer/grammarly/test/source
# !mv /content/FormalityStyleTransfer/grammarly/test/formal.ref0 /content/FormalityStyleTransfer/grammarly/test/target

# %%
# !mv /content/FormalityStyleTransfer/grammarly/val/informal /content/FormalityStyleTransfer/grammarly/val/source
# !mv /content/FormalityStyleTransfer/grammarly/val/formal.ref0 /content/FormalityStyleTransfer/grammarly/val/target

# %%
# !mv /content/FormalityStyleTransfer/grammarly/plain/informal /content/FormalityStyleTransfer/grammarly/plain/source
# !mv /content/FormalityStyleTransfer/grammarly/plain/formal.ref0 /content/FormalityStyleTransfer/grammarly/plain/target

# %%
# %cd /content/FormalityStyleTransfer
# Out:
# /content/FormalityStyleTransfer

# %%
# !cp /content/drive/MyDrive/FormalityStyleTransfer/multiprocessing_bpe_encoder.py ./
# !cp /content/drive/MyDrive/FormalityStyleTransfer/preprocess.sh ./
# !cp /content/drive/MyDrive/FormalityStyleTransfer/pipeline.sh ./

# %%
# !pip install --editable ./
# Out:
# Obtaining file:///content/FormalityStyleTransfer
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 90 kB 6.3 MB/s
# ...
#   Running setup.py develop for fairseq
# ...

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing fairseq.egg-info/PKG-INFO
# writing dependency_links to fairseq.egg-info/dependency_links.txt
# writing entry points to fairseq.egg-info/entry_points.txt
# writing requirements to fairseq.egg-info/requires.txt
# writing top-level names to fairseq.egg-info/top_level.txt
# /usr/local/lib/python3.7/dist-packages/torch/utils/cpp_extension.py:381: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# adding license file 'LICENSE'
# writing manifest file 'fairseq.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/lib.linux-x86_64-3.7/fairseq_cli
# copying fairseq_cli/score.py -> build/lib.linux-x86_64-3.7/fairseq_cli
# ...

# %%
# !bash preprocess.sh
# Out:
# --2022-01-02 18:04:37--  https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/encoder.json
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘encoder.json’ not modified on server. Omitting download.
#
# --2022-01-02 18:04:38--  https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/vocab.bpe
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘vocab.bpe’ not modified on server. Omitting download.
#
# --2022-01-02 18:04:38--  https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/dict.txt
# ...

# %%
# !for file in /content/FormalityStyleTransfer/grammarly-bin/test.source-target.* ; do cp "$file" "${file/test/plain}" ; done

# %%
#!wget https://dl.fbaipublicfiles.com/fairseq/models/bart.large.tar.gz
#!tar -xf bart.large.tar.gz

# %%
# !tar -xf /content/drive/MyDrive/FormalityStyleTransfer/bart.large.tar.gz

# %%
# !bash pipeline.sh
# Out:
# 2022-01-02 18:37:51 | INFO | fairseq_cli.train | Namespace(activation_fn='gelu', adam_betas='(0.9, 0.999)', adam_eps=1e-08, adaptive_softmax_cutoff=None, adaptive_softmax_dropout=0, all_gather_list_size=16384, arch='bart_large', attention_dropout=0.1, best_checkpoint_metric='nll_loss', bpe=None, broadcast_buffers=False, bucket_cap_mb=25, clip_norm=0.1, cpu=False, criterion='label_smoothed_cross_entropy', cross_self_attention=False, curriculum=0, cycle_weight=0.6, data='grammarly-bin', dataset_impl=None, ddp_backend='c10d', decoder_attention_heads=16, decoder_embed_dim=1024, decoder_embed_path=None, decoder_ffn_embed_dim=4096, decoder_input_dim=1024, decoder_layerdrop=0, decoder_layers=12, decoder_layers_to_keep=None, decoder_learned_pos=True, decoder_normalize_before=False, decoder_output_dim=1024, device_id=0, disable_validation=False, disc_epochs=10, disc_weight=1.0, distributed_backend='nccl', distributed_init_method=None, distributed_no_spawn=False, distributed_port=-1, distribut
# ...
